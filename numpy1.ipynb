# %% [markdown]
# numpy means numerical python
# numpy is fast: fast kind of list.
# its 10x faster than our normal list
# it has its own unique type
# its a very broad library
# it can take the form of a tuple and/or a list.
#
# properties of numpy
# -it has its own unique type called numpy.ndArray
# -its made up of dimensions
# -it has 1 dimensional array, two dimensional array and 3 dimensional array
# -the length of each dimension should remain equal across each dimension type
# -lists and tuples in numpy are generally called arrays
#
#
#
# -dtype identifies the type of integer in a numpy list
# adding example dtype = "i" changes the type of number to an integer and vice versa
#
#
# int32 is a smaller box compared to int64 that is a much bigger box. int can hold up to 2billion in numers and uses 32 bit of space
# while int64 uses 64 bits of space and can hold numers up to 9queentrillion(18 zeros)
# both can hold it in negative and positive
#
#
# 1D (one dimension) array is simply a list or tuple
# 2D Array is a table and matrix - because we have row and column i.e 2 dimension
#     0 axis - rows
#     1 axis - column
#
# 3D Array is a stack of 2D Eg stacks os table or matrix
#     0 axis - depth
#     1 axis - rows
#     2 axis - column

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'
